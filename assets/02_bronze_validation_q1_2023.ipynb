# %% [markdown]
# # SQL Bronze validation

# %%
# %sql
-- Bronze validation (Q1 2023)

SELECT COUNT(*) AS total_rows
FROM taxi_lakehouse.bronze.yellow_taxi_q1_2023;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_rows</th></tr></thead><tbody><tr><td>9384487</td></tr></tbody></table></div>

# %%
# %sql
SELECT _source_file, COUNT(*) AS rows
FROM taxi_lakehouse.bronze.yellow_taxi_q1_2023
GROUP BY _source_file
ORDER BY _source_file;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_source_file</th><th>rows</th></tr></thead><tbody><tr><td>/Volumes/taxi_lakehouse/bronze/raw_files/yellow_tripdata_2023-01.parquet</td><td>3066766</td></tr><tr><td>/Volumes/taxi_lakehouse/bronze/raw_files/yellow_tripdata_2023-02.parquet</td><td>2913955</td></tr><tr><td>/Volumes/taxi_lakehouse/bronze/raw_files/yellow_tripdata_2023-03.parquet</td><td>3403766</td></tr></tbody></table></div>
